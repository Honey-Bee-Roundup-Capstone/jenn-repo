# %%
import pandas as pd

# %%
# old_bee_data = pd.read_csv("../Data/bee_colony_survey_data_by_state.csv")
# new_bee_data = pd.read_csv("../Data/bee_colony_survey_data_by_state_2018_2022.csv")

# %%
# colony_loss_data = pd.read_excel("../Data/bee_colony_loss.xlsx")

# %%
# census_data = pd.read_csv("../Data/bee_colony_census_data_by_county.csv")

# %%
# colony_loss_data.to_csv("../Data/bee_colony_loss.csv")

# %%
# colony_loss = pd.read_csv("../Data/bee_colony_loss.csv")

# %%
# colony_loss.count()

# %%
# colony_loss.columns

# %%
# colony_loss.head()

# %%
# old_bee_data.head()

# %%
# new_bee_data.head()

# %%
# colony_loss.head()

# %%
# colony_loss.Season.unique()

# %%
# del colony_loss["Unnamed: 0"]
# del colony_loss['Season']

# %%
# colony_loss.columns = "year", "state", "total_annual_loss", "beekeepers", "beekeepers_exclusive_to_state", "colonies", "colonies_exclusive_to_state"

# %%
# colony_loss.head()

# %%
# colony_loss.info()

# %%
# colony_loss.to_csv("bee_colony_loss_standardized.csv")

# %%
# census_data.head()

# %%
# census_data.info()

# %%
# old_bee_data.head()

# %%
# old_bee_data["Week Ending"].unique()

# %%
# new_bee_data.head()

# %%
# old_bee_data.columns

# %%
# colony_loss.columns

# %%
# old_bee_data["Data Item"].unique()

# %%
# colony_loss.total_annual_loss.unique()

# %%
# old_bee_data["Week Ending"].unique()

# %%
# colony_loss.year.unique()

# %%
# old_bee_data.columns

# %%
# old_bee_data.columns = "year", "period", "week_ending", "state", "state_ansi", "watershed", "data_item", "value", "cv_percent"
# old_bee_data.head()

# %%
# cols = ["period", 'state', 'data_item']

# %%
# for col in cols:
#     old_bee_data[col] = old_bee_data[col].str.lower()

# %%
# old_bee_data.head()

# %%
bcl = pd.read_csv("BeeInformed_States_Loss_Table_by_Year_public_ready_2022.csv")
bcl.head()
# Out:
#   Column name as written in R Script Full State name State abbreviation  \
# 0                              State           state           initials
# 1                       TF_States_AL         Alabama                 AL
# 2                       TF_States_AK          Alaska                 AK
# 3                       TF_States_AZ         Arizona                 AZ
# 4                       TF_States_AR        Arkansas                 AR
#
#   Survey Year  Season  \
# 0  SurveyYear  Season
# 1        2008  Annual
# 2        2008  Annual
# 3        2008  Annual
# 4        2008  Annual
#
#   Method of tallying multi-states operations (included in all states, excluded from all states, exlusively multi-states)  \
# 0                                             Method
# 1                                             MSO in
# 2                                             MSO in
# 3                                             MSO in
# 4                                             MSO in
# ...

# %%
bcl["Survey Year"].value_counts()
# Out:
# 2008          468
# 2009          468
# 2010          468
# 2011          468
# 2012          468
# 2013          468
# 2014          468
# 2015          468
# 2016          468
# 2017          468
# 2018          468
# 2019          468
# 2020          468
# 2021          468
# 2022          468
# SurveyYear      1
# Name: Survey Year, dtype: int64

# %%
bcl.columns
# Out:
# Index(['Column name as written in R Script', 'Full State name',
#        'State abbreviation', 'Survey Year', 'Season',
#        'Method of tallying multi-states operations (included in all states, excluded from all states, exlusively multi-states)',
#        'Number of valid respondents', 'Bootstrap replication',
#        'Bootstrap method',
#        'Bootstrap estimate of the Total Loss (weigthed average)',
#        'Boostrap-based 95% confidence interval(low) of the weighted average loss',
#        'Boostrap-based 95% confidence interval(high) of the weighted average loss',
#        'Bootstrap estimate of the Average Loss (unweigthed average)',
#        'Boostrap-based 95% confidence interval(low) of the unweighted average loss',
#        'Boostrap-based 95% confidence interval(high) of the unweighted average loss',
#        'Total Loss (weigthed average)',
#        'glm-based 95% confidence interval(low) of the weighted average loss',
# ...

# %%
bcl = bcl.drop(columns=["Column name as written in R Script", 'State abbreviation', "Method of tallying multi-states operations (included in all states, excluded from all states, exlusively multi-states)", 
       'Bootstrap replication',
       'Bootstrap method',
       'Bootstrap estimate of the Total Loss (weigthed average)',
       'Boostrap-based 95% confidence interval(low) of the weighted average loss',
       'Boostrap-based 95% confidence interval(high) of the weighted average loss',
       'Bootstrap estimate of the Average Loss (unweigthed average)',
       'Boostrap-based 95% confidence interval(low) of the unweighted average loss',
       'Boostrap-based 95% confidence interval(high) of the unweighted average loss',
       'glm-based 95% confidence interval(low) of the weighted average loss',
       'glm-based 95% confidence interval(high) of the weighted average loss',
       'standard deviation of operational losses',
       'standard error of the unweithed average estimate',
       'glm-based 95% confidence interval(low) of the unweighted average loss',
       'glm-based 95% confidence interval(high) of the unweighted average loss',
       'Total number of colonies "at risk" (colonies at the start, new colonies added, without colonies sold or given away)'])
bcl.head()
# Out:
#   Full State name Survey Year  Season Number of valid respondents  \
# 0           state  SurveyYear  Season                           N
# 1         Alabama        2008  Annual                           0
# 2          Alaska        2008  Annual                           0
# 3         Arizona        2008  Annual                           0
# 4        Arkansas        2008  Annual                           0
#
#   Total Loss (weigthed average) Average Loss (unweigthed average)  \
# 0                            TL                                AL
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#   Total number of colonies at the start of the season  \
# 0                                      TotalColStart
# 1                                                  0
# ...

# %%
bcl = bcl.iloc[1:, :]

# %%
bcl.head()
# Out:
#   Full State name Survey Year  Season Number of valid respondents  \
# 1         Alabama        2008  Annual                           0
# 2          Alaska        2008  Annual                           0
# 3         Arizona        2008  Annual                           0
# 4        Arkansas        2008  Annual                           0
# 5      California        2008  Annual                           0
#
#   Total Loss (weigthed average) Average Loss (unweigthed average)  \
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
# 5                           NaN                               NaN
#
#   Total number of colonies at the start of the season  \
# 1                                                  0
# 2                                                  0
# ...

# %%
bcl.columns = ["state", "year", "season", "beekeepers", "total_loss", "average_loss", "starting_colonies", "colonies_lost", "ending_colonies", "beekeepers_exclusive_to_state", "colonies_exclusive_to_state"]

# %%
bcl[bcl["year"] == "2008"]
# Out:
#                     state  year  season beekeepers   total_loss average_loss  \
# 1                 Alabama  2008  Annual          0          NaN          NaN
# 2                  Alaska  2008  Annual          0          NaN          NaN
# 3                 Arizona  2008  Annual          0          NaN          NaN
# 4                Arkansas  2008  Annual          0          NaN          NaN
# 5              California  2008  Annual          0          NaN          NaN
# ...                   ...   ...     ...        ...          ...          ...
# 4832        West Virginia  2008  Winter         16   35.1305813    27.295408
# 4833            Wisconsin  2008  Winter         14  66.21900826  51.69457453
# 4834              Wyoming  2008  Winter          0          NaN          NaN
# 4835  Non Continental USA  2008  Winter          0          NaN          NaN
# 4836          MultiStates  2008  Winter         43  31.15699173  29.76307293
#
# ...

# %%
bcl = pd.read_csv("bee_colony_loss.csv")
del bcl["Unnamed: 0"]

# %%
bcl.dtypes
# Out:
# state                             object
# year                               int64
# season                            object
# beekeepers                         int64
# total_loss                        object
# average_loss                      object
# starting_colonies                  int64
# colonies_lost                     object
# ending_colonies                   object
# beekeepers_exclusive_to_state    float64
# colonies_exclusive_to_state      float64
# dtype: object

# %%
bcl[bcl.colonies_lost == "[R]"]
# Out:
#                     state  year  season  beekeepers total_loss average_loss  \
# 106               Arizona  2008  Winter           1        [R]          [R]
# 109              Colorado  2008  Winter           3        [R]          [R]
# 115                 Idaho  2008  Winter           1        [R]          [R]
# 116              Illinois  2008  Winter           1        [R]          [R]
# 119                Kansas  2008  Winter           1        [R]          [R]
# ...                   ...   ...     ...         ...        ...          ...
# 6991          Mississippi  2022  Winter           5        [R]          [R]
# 6995               Nevada  2022  Winter           8        [R]          [R]
# 7001         North Dakota  2022  Winter           1        [R]          [R]
# 7017              Wyoming  2022  Winter           8        [R]          [R]
# 7018  Non Continental USA  2022  Winter           7        [R]          [R]
#
#       starting_colonies colonies_lost ending_colonies  \
# ...

# %%
bcl = bcl[bcl.season == "Annual"]

# %%
bcl = bcl[bcl.state != "Non Continental USA"]

# %%
bcl = bcl[bcl.state != "MultiStates"]

# %%
bcl.loc[bcl.starting_colonies == 0].total_loss = bcl[bcl.starting_colonies == 0].total_loss.fillna("0")
# Out:
# /var/folders/q3/1b2t5ssx44b5gc0gsnqnd4ww0000gn/T/ipykernel_2818/3259645999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcl.loc[bcl.starting_colonies == 0].total_loss = bcl[bcl.starting_colonies == 0].total_loss.fillna("0")

# %%
bcl = bcl[bcl.state != "District of Columbia"]

# %%
bcl.state.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
bcl = bcl[bcl.beekeepers > 10]

# %%
bcl.head()
# Out:
#            state  year  season  beekeepers   total_loss average_loss  \
# 468      Alabama  2011  Annual          19  14.15929204   27.0136238
# 471     Arkansas  2011  Annual          14  31.57894737  19.76540616
# 472   California  2011  Annual         142  35.55825336  41.42370845
# 473     Colorado  2011  Annual          61  38.22714681  33.80939165
# 474  Connecticut  2011  Annual          42  43.11926606  47.33394648
#
#      starting_colonies colonies_lost ending_colonies  \
# 468                307            64             388
# 471                 49            24              52
# 472              84959         46278           83869
# 473                403           276             446
# 474                389           282             372
#
#      beekeepers_exclusive_to_state  colonies_exclusive_to_state
# 468                      94.736842                    96.091205
# 471                      85.714286                    79.591837
# ...

# %%
bcl.year.unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022])
